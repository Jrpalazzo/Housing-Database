# %%
import sqlite3
import pandas as pd

# %%
#//////////////////////////Create the geography csv file//////////////////////////////////////////////////

# %%
#//check if the data has all the same rows 
d1 = pd.read_csv('./PEP_2018_PEPANNHU_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)

d2 = pd.read_csv('./ACS_15_5YR_S1901_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)

d3 = pd.read_csv('./ACS_16_5YR_S1901_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)

d4 = pd.read_csv('./ACS_17_5YR_S1901_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)

d5 = pd.read_csv('./ACS_15_1YR_S2301_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)

d6 = pd.read_csv('./ACS_16_1YR_S2301_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)

d7 = pd.read_csv('./ACS_17_1YR_S2301_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)

# %%
d1.shape
# Out:
# (3142, 14)

# %%
d2.shape
# Out:
# (3142, 107)

# %%
d3.shape
# Out:
# (3142, 107)

# %%
d4.shape
# Out:
# (3142, 107)

# %%
d5.shape
# Out:
# (819, 91)

# %%
d6.shape
# Out:
# (820, 91)

# %%
d7.shape
# Out:
# (826, 91)

# %%
#make sure we have all the counties
d_combined = pd.concat([d1, d2, d5], sort=False)
d_combined.head(3)
# Out:
#                Id   Id2                Geography  April 1, 2010 - Census  \
# 0  0500000US01001  1001  Autauga County, Alabama                 22135.0
# 1  0500000US01003  1003  Baldwin County, Alabama                104061.0
# 2  0500000US01005  1005  Barbour County, Alabama                 11829.0
#
#    April 1, 2010 - Estimates Base  \
# 0                         22136.0
# 1                        104060.0
# 2                         11829.0
#
#    Housing Unit Estimate (as of July 1) - 2010  \
# 0                                      22166.0
# 1                                     104292.0
# 2                                      11832.0
#
#    Housing Unit Estimate (as of July 1) - 2011  \
# 0                                      22351.0
# 1                                     104930.0
# 2                                      11841.0
#
#    Housing Unit Estimate (as of July 1) - 2012  \
# 0                                      22471.0
# ...

# %%
#drop all columns from range 3 to 206
d_combined_dropped = d_combined.drop(d_combined.iloc[:, 3:206], axis=1)
d_combined_dropped.head(3)
# Out:
#                Id   Id2                Geography
# 0  0500000US01001  1001  Autauga County, Alabama
# 1  0500000US01003  1003  Baldwin County, Alabama
# 2  0500000US01005  1005  Barbour County, Alabama

# %%
d_combined_dropped.drop_duplicates(subset=['Geography'],inplace=True) 
d_combined_dropped.head()
# Out:
#                Id   Id2                Geography
# 0  0500000US01001  1001  Autauga County, Alabama
# 1  0500000US01003  1003  Baldwin County, Alabama
# 2  0500000US01005  1005  Barbour County, Alabama
# 3  0500000US01007  1007     Bibb County, Alabama
# 4  0500000US01009  1009   Blount County, Alabama

# %%
#split state and county 
d_combined_dropped[['county', 'state']] = (d_combined_dropped['Geography']         
            .str.split(', ', n=1, expand=True))  
                                                                
data_geo = d_combined_dropped.drop(columns = ['Geography'])
data_geo.head(3)
# Out:
#                Id   Id2          county    state
# 0  0500000US01001  1001  Autauga County  Alabama
# 1  0500000US01003  1003  Baldwin County  Alabama
# 2  0500000US01005  1005  Barbour County  Alabama

# %%
data_geo.duplicated(subset = ['county','state'], keep=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 3112    False
# 3113    False
# 3114    False
# 3115    False
# 3116    False
# 3117    False
# 3118    False
# 3119    False
# 3120    False
# 3121    False
# 3122    False
# 3123    False
# 3124    False
# 3125    False
# 3126    False
# 3127    False
# 3128    False
# 3129    False
# 3130    False
# 3131    False
# 3132    False
# 3133    False
# 3134    False
# 3135    False
# 3136    False
# 3137    False
# 3138    False
# 3139    False
# 3140    False
# 3141    False
# ...

# %%
data_geo.shape
# Out:
# (3142, 4)

# %%
data_geo.to_csv('location_data.csv', index=False) #store data set to a new csv file

# %%
#//////////////////////////Explore the Housing File/////////////////////////////////////////////////////

# %%
df = pd.read_csv('./PEP_2018_PEPANNHU_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)

# %%
df.head
# Out:
# <bound method NDFrame.head of                   Id    Id2                     Geography  \
# 0     0500000US01001   1001       Autauga County, Alabama
# 1     0500000US01003   1003       Baldwin County, Alabama
# 2     0500000US01005   1005       Barbour County, Alabama
# 3     0500000US01007   1007          Bibb County, Alabama
# 4     0500000US01009   1009        Blount County, Alabama
# 5     0500000US01011   1011       Bullock County, Alabama
# 6     0500000US01013   1013        Butler County, Alabama
# 7     0500000US01015   1015       Calhoun County, Alabama
# 8     0500000US01017   1017      Chambers County, Alabama
# 9     0500000US01019   1019      Cherokee County, Alabama
# 10    0500000US01021   1021       Chilton County, Alabama
# 11    0500000US01023   1023       Choctaw County, Alabama
# 12    0500000US01025   1025        Clarke County, Alabama
# 13    0500000US01027   1027          Clay County, Alabama
# 14    0500000US01029   1029      Cleburne County, Alabama
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Id2', 'Geography', 'April 1, 2010 - Census',
#        'April 1, 2010 - Estimates Base',
#        'Housing Unit Estimate (as of July 1) - 2010',
#        'Housing Unit Estimate (as of July 1) - 2011',
#        'Housing Unit Estimate (as of July 1) - 2012',
#        'Housing Unit Estimate (as of July 1) - 2013',
#        'Housing Unit Estimate (as of July 1) - 2014',
#        'Housing Unit Estimate (as of July 1) - 2015',
#        'Housing Unit Estimate (as of July 1) - 2016',
#        'Housing Unit Estimate (as of July 1) - 2017',
#        'Housing Unit Estimate (as of July 1) - 2018'],
#       dtype='object')

# %%
df.values
# Out:
# array([['0500000US01001', 1001, 'Autauga County, Alabama', ..., 23280,
#         23494, 23734],
#        ['0500000US01003', 1003, 'Baldwin County, Alabama', ..., 111579,
#         114134, 116631],
#        ['0500000US01005', 1005, 'Barbour County, Alabama', ..., 11940,
#         11970, 12005],
#        ...,
#        ['0500000US56041', 56041, 'Uinta County, Wyoming', ..., 8972,
#         9018, 9060],
#        ['0500000US56043', 56043, 'Washakie County, Wyoming', ..., 3864,
#         3867, 3870],
#        ['0500000US56045', 56045, 'Weston County, Wyoming', ..., 3563,
#         3566, 3567]], dtype=object)

# %%
df.shape #3142 rows, 14 columns
# Out:
# (3142, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3142 entries, 0 to 3141
# Data columns (total 14 columns):
# Id                                             3142 non-null object
# Id2                                            3142 non-null int64
# Geography                                      3142 non-null object
# April 1, 2010 - Census                         3142 non-null int64
# April 1, 2010 - Estimates Base                 3142 non-null int64
# Housing Unit Estimate (as of July 1) - 2010    3142 non-null int64
# Housing Unit Estimate (as of July 1) - 2011    3142 non-null int64
# Housing Unit Estimate (as of July 1) - 2012    3142 non-null int64
# Housing Unit Estimate (as of July 1) - 2013    3142 non-null int64
# Housing Unit Estimate (as of July 1) - 2014    3142 non-null int64
# Housing Unit Estimate (as of July 1) - 2015    3142 non-null int64
# Housing Unit Estimate (as of July 1) - 2016    3142 non-null int64
# ...

# %%
census = df['April 1, 2010 - Census']

# %%
census.head()
# Out:
# 0     22135
# 1    104061
# 2     11829
# 3      8981
# 4     23887
# Name: April 1, 2010 - Census, dtype: int64

# %%
type(census)
# Out:
# pandas.core.series.Series

# %%
estimates = df['April 1, 2010 - Estimates Base']

# %%
estimates.head()
# Out:
# 0     22136
# 1    104060
# 2     11829
# 3      8984
# 4     23887
# Name: April 1, 2010 - Estimates Base, dtype: int64

# %%
type(estimates)
# Out:
# pandas.core.series.Series

# %%
data_dropped = df.drop(columns=['April 1, 2010 - Census', 'April 1, 2010 - Estimates Base'])

# %%
data_dropped.columns
# Out:
# Index(['Id', 'Id2', 'Geography', 'Housing Unit Estimate (as of July 1) - 2010',
#        'Housing Unit Estimate (as of July 1) - 2011',
#        'Housing Unit Estimate (as of July 1) - 2012',
#        'Housing Unit Estimate (as of July 1) - 2013',
#        'Housing Unit Estimate (as of July 1) - 2014',
#        'Housing Unit Estimate (as of July 1) - 2015',
#        'Housing Unit Estimate (as of July 1) - 2016',
#        'Housing Unit Estimate (as of July 1) - 2017',
#        'Housing Unit Estimate (as of July 1) - 2018'],
#       dtype='object')

# %%
#////////////////////////// Tidy the Housing File /////////////////////////////////////////////////////

# %%
data_long = (pd.melt(data_dropped, id_vars = ['Id', 'Id2','Geography']
                     , var_name = 'year', value_name = 'housing_estimate' ))
#data_long_edited = data_long['year'].str.replace('Housing', 'year')

# %%
data_long.head(3)
# Out:
#                Id   Id2                Geography  \
# 0  0500000US01001  1001  Autauga County, Alabama
# 1  0500000US01003  1003  Baldwin County, Alabama
# 2  0500000US01005  1005  Barbour County, Alabama
#
#                                           year  housing_estimate
# 0  Housing Unit Estimate (as of July 1) - 2010             22166
# 1  Housing Unit Estimate (as of July 1) - 2010            104292
# 2  Housing Unit Estimate (as of July 1) - 2010             11832

# %%
#split state and county 
data_long[['county', 'state']] = (data_long['Geography'].str.split(", ", 1, expand=True))

data_housing = data_long.drop(columns = ['Geography'])
data_housing.head(3)
# Out:
#                Id   Id2                                         year  \
# 0  0500000US01001  1001  Housing Unit Estimate (as of July 1) - 2010
# 1  0500000US01003  1003  Housing Unit Estimate (as of July 1) - 2010
# 2  0500000US01005  1005  Housing Unit Estimate (as of July 1) - 2010
#
#    housing_estimate          county    state
# 0             22166  Autauga County  Alabama
# 1            104292  Baldwin County  Alabama
# 2             11832  Barbour County  Alabama

# %%
#split state and county 
data_housing['year']= data_housing['year'].str.split('-').str[-1]
#data_housing_dropped = data_housing.drop(columns = 'state')
#data_housing_dropped.head(3)

# %%
data_housing.duplicated(subset = ['housing_estimate','county','year'], keep=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 28248    False
# 28249    False
# 28250    False
# 28251    False
# 28252    False
# 28253    False
# 28254    False
# 28255    False
# 28256    False
# 28257    False
# 28258    False
# 28259    False
# 28260    False
# 28261    False
# 28262    False
# 28263    False
# 28264    False
# 28265    False
# 28266    False
# 28267    False
# 28268    False
# 28269    False
# 28270    False
# 28271    False
# 28272    False
# 28273    False
# 28274    False
# ...

# %%
data_housing.shape
# Out:
# (28278, 6)

# %%
data_housing.to_csv('housing_data.csv', index=False) #store data set to a new csv file

# %%
#//////////////////////////Explore the Employment Files//////////////////////////////////////////////////

# %%
#we need to create a new year column
df_employ0 = pd.read_csv('./ACS_15_1YR_S2301_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)
df_employ0 = df_employ0.assign(year = ['2015']*len(df_employ0.index))

df_employ1 = pd.read_csv('./ACS_16_1YR_S2301_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)
df_employ1 = df_employ1.assign(year = ['2016']*len(df_employ1.index))

df_employ2 = pd.read_csv('./ACS_17_1YR_S2301_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)
df_employ2 = df_employ2.assign(year = ['2017']*len(df_employ2.index))

# %%
df_employ = pd.concat([df_employ0, df_employ1, df_employ2], sort=False)
df_employ.head(3)
# Out:
#                Id   Id2                Geography  \
# 0  0500000US01003  1003  Baldwin County, Alabama
# 1  0500000US01015  1015  Calhoun County, Alabama
# 2  0500000US01043  1043  Cullman County, Alabama
#
#   Total; Estimate; Population 16 years and over  \
# 0                                        164125
# 1                                         93323
# 2                                         66026
#
#   Total; Margin of Error; Population 16 years and over  \
# 0                                                784
# 1                                                691
# 2                                                375
#
#   Labor Force Participation Rate; Estimate; Population 16 years and over  \
# 0                                               56.4
# 1                                               56.5
# 2                                               49.0
#
#   Labor Force Participation Rate; Margin of Error; Population 16 years and over  \
# ...

# %%
#drop all columns from range 11 to 91
df_dropped = df_employ.drop(df_employ.iloc[:, 11:91], axis=1)

# %%
df_dropped.head()
# Out:
#                Id   Id2                Geography  \
# 0  0500000US01003  1003  Baldwin County, Alabama
# 1  0500000US01015  1015  Calhoun County, Alabama
# 2  0500000US01043  1043  Cullman County, Alabama
# 3  0500000US01049  1049   DeKalb County, Alabama
# 4  0500000US01051  1051   Elmore County, Alabama
#
#   Total; Estimate; Population 16 years and over  \
# 0                                        164125
# 1                                         93323
# 2                                         66026
# 3                                         55330
# 4                                         64989
#
#   Total; Margin of Error; Population 16 years and over  \
# 0                                                784
# 1                                                691
# 2                                                375
# 3                                                750
# 4                                                439
#
# ...

# %%
df_dropped.head(3)
# Out:
#                Id   Id2                Geography  \
# 0  0500000US01003  1003  Baldwin County, Alabama
# 1  0500000US01015  1015  Calhoun County, Alabama
# 2  0500000US01043  1043  Cullman County, Alabama
#
#   Total; Estimate; Population 16 years and over  \
# 0                                        164125
# 1                                         93323
# 2                                         66026
#
#   Total; Margin of Error; Population 16 years and over  \
# 0                                                784
# 1                                                691
# 2                                                375
#
#   Labor Force Participation Rate; Estimate; Population 16 years and over  \
# 0                                               56.4
# 1                                               56.5
# 2                                               49.0
#
#   Labor Force Participation Rate; Margin of Error; Population 16 years and over  \
# ...

# %%
#split state and county 
df_dropped[['county', 'state']] = (df_dropped['Geography'].str.split(", ", 1, expand=True))   
data_employment = df_dropped.drop(columns = ['Geography']) #warning state column dropped!
data_employment.head(3)
# Out:
#                Id   Id2 Total; Estimate; Population 16 years and over  \
# 0  0500000US01003  1003                                        164125
# 1  0500000US01015  1015                                         93323
# 2  0500000US01043  1043                                         66026
#
#   Total; Margin of Error; Population 16 years and over  \
# 0                                                784
# 1                                                691
# 2                                                375
#
#   Labor Force Participation Rate; Estimate; Population 16 years and over  \
# 0                                               56.4
# 1                                               56.5
# 2                                               49.0
#
#   Labor Force Participation Rate; Margin of Error; Population 16 years and over  \
# 0                                                2.3
# 1                                                2.7
# ...

# %%
data_employment.to_csv('employment_data.csv', index=False) #store data set to a new csv file

# %%
#//////////////////////////Explore the Income Files/////////////////////////////////////////////////////

# %%
#we need to create a new year column
df_income0 = pd.read_csv('./ACS_15_5YR_S1901_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)
df_income0 = df_income0.assign(year = ['2015']*len(df_income0.index))

df_income1 = pd.read_csv('./ACS_16_5YR_S1901_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)
df_income1 = df_income1.assign(year = ['2016']*len(df_income1.index))

df_income2 = pd.read_csv('./ACS_17_5YR_S1901_with_ann.csv',encoding = "ISO-8859-1",skiprows=1)
df_income2 = df_income2.assign(year = ['2017']*len(df_income2.index))

# %%
df_income = pd.concat([df_income0, df_income1, df_income2])
list(df_income)
# Out:
# ['Id',
#  'Id2',
#  'Geography',
#  'Households; Estimate; Total',
#  'Households; Margin of Error; Total',
#  'Families; Estimate; Total',
#  'Families; Margin of Error; Total',
#  'Married-couple families; Estimate; Total',
#  'Married-couple families; Margin of Error; Total',
#  'Nonfamily households; Estimate; Total',
#  'Nonfamily households; Margin of Error; Total',
#  'Households; Estimate; Less than $10,000',
#  'Households; Margin of Error; Less than $10,000',
#  'Families; Estimate; Less than $10,000',
#  'Families; Margin of Error; Less than $10,000',
#  'Married-couple families; Estimate; Less than $10,000',
#  'Married-couple families; Margin of Error; Less than $10,000',
#  'Nonfamily households; Estimate; Less than $10,000',
#  'Nonfamily households; Margin of Error; Less than $10,000',
#  'Households; Estimate; $10,000 to $14,999',
#  'Households; Margin of Error; $10,000 to $14,999',
#  'Families; Estimate; $10,000 to $14,999',
# ...

# %%
df_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9426 entries, 0 to 3141
# Columns: 108 entries, Id to year
# dtypes: float64(80), int64(17), object(11)
# memory usage: 7.8+ MB

# %%
list(df_income)
# Out:
# ['Id',
#  'Id2',
#  'Geography',
#  'Households; Estimate; Total',
#  'Households; Margin of Error; Total',
#  'Families; Estimate; Total',
#  'Families; Margin of Error; Total',
#  'Married-couple families; Estimate; Total',
#  'Married-couple families; Margin of Error; Total',
#  'Nonfamily households; Estimate; Total',
#  'Nonfamily households; Margin of Error; Total',
#  'Households; Estimate; Less than $10,000',
#  'Households; Margin of Error; Less than $10,000',
#  'Families; Estimate; Less than $10,000',
#  'Families; Margin of Error; Less than $10,000',
#  'Married-couple families; Estimate; Less than $10,000',
#  'Married-couple families; Margin of Error; Less than $10,000',
#  'Nonfamily households; Estimate; Less than $10,000',
#  'Nonfamily households; Margin of Error; Less than $10,000',
#  'Households; Estimate; $10,000 to $14,999',
#  'Households; Margin of Error; $10,000 to $14,999',
#  'Families; Estimate; $10,000 to $14,999',
# ...

# %%
#df.drop(list(df.filter(regex = 'Test')), axis = 1, inplace = True)
#get all the columns that we don't need and drop them by finding a part of the word with 'like'
drop_income = df_income.drop(df_income.filter(like='Families',axis=1).columns,axis=1)
drop_income2 = drop_income.drop(drop_income.filter(like='Married',axis=1).columns,axis=1)
drop_income3 = drop_income2.drop(drop_income2.filter(like='Nonfamily',axis=1).columns,axis=1)
drop_income4 = drop_income3.drop(drop_income3.iloc[:, 3:23], axis=1)
#data_long_income = (pd.melt(drop_income5, id_vars = ['Geography', 'year']
#                     , var_name = 'housing', value_name = 'housing_data' ))

# %%
drop_income4.head(3)
# Out:
#                Id   Id2                Geography  \
# 0  0500000US01001  1001  Autauga County, Alabama
# 1  0500000US01003  1003  Baldwin County, Alabama
# 2  0500000US01005  1005  Barbour County, Alabama
#
#    Households; Estimate; $200,000 or more  \
# 0                                     2.4
# 1                                     3.9
# 2                                     0.7
#
#    Households; Margin of Error; $200,000 or more  \
# 0                                            0.9
# 1                                            0.5
# 2                                            0.3
#
#   Households; Estimate; Median income (dollars)  \
# 0                                         51281
# 1                                         50254
# 2                                         32964
#
#   Households; Margin of Error; Median income (dollars)  \
# 0                                               2391
# 1                                               1263
# ...

# %%
#split state and county 
#drop columns we don't need
drop_income4 = drop_income4.drop(columns = ['Households; Estimate; $200,000 or more', 'Households; Margin of Error; $200,000 or more'
                                            ,'Households; Margin of Error; Median income (dollars)', 'Households; Margin of Error; Mean income (dollars)'])
drop_income4[['county', 'state']] = (drop_income4['Geography'].str.split(", ", 1, expand=True))            
data_income = drop_income4.drop(columns = ['Geography'])
data_income.head(3)
# Out:
#                Id   Id2 Households; Estimate; Median income (dollars)  \
# 0  0500000US01001  1001                                         51281
# 1  0500000US01003  1003                                         50254
# 2  0500000US01005  1005                                         32964
#
#    Households; Estimate; Mean income (dollars)  year          county    state
# 0                                        64765  2015  Autauga County  Alabama
# 1                                        68169  2015  Baldwin County  Alabama
# 2                                        44688  2015  Barbour County  Alabama

# %%
data_income.to_csv('income_data.csv', index=False) #store data set to a new csv file
